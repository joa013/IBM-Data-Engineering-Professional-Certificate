# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkPY0221ENSkillsNetwork23455645-2022-01-01" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo"  />
#     </a>
# </p>

# %% [markdown]
# # Peer Review Assignment - Data Engineer - Extract API Data

# %% [markdown]
# Estimated time needed: **20** minutes

# %% [markdown]
# ## Objectives
#
# In this part you will:
#
# *   Collect exchange rate data using an API
# *   Store the data as a CSV

# %% [markdown]
# For this lab, we are going to be using Python and several Python libraries. Some of these libraries might be installed in your lab environment or in SN Labs. Others may need to be installed by you. The cells below will install these libraries when executed.

# %%
# !mamba install pandas==1.3.3 -y
# !mamba install requests==2.26.0 -y
# Out:
#                   __    __    __    __
#                  /  \  /  \  /  \  /  \
#                 /    \/    \/    \/    \
# ███████████████/  /██/  /██/  /██/  /████████████████████████
#               /  / \   / \   / \   / \  \____
#              /  /   \_/   \_/   \_/   \    o \__,
#             / _/                       \_____/  `
#             |/
#         ███╗   ███╗ █████╗ ███╗   ███╗██████╗  █████╗
#         ████╗ ████║██╔══██╗████╗ ████║██╔══██╗██╔══██╗
#         ██╔████╔██║███████║██╔████╔██║██████╔╝███████║
#         ██║╚██╔╝██║██╔══██║██║╚██╔╝██║██╔══██╗██╔══██║
#         ██║ ╚═╝ ██║██║  ██║██║ ╚═╝ ██║██████╔╝██║  ██║
#         ╚═╝     ╚═╝╚═╝  ╚═╝╚═╝     ╚═╝╚═════╝ ╚═╝  ╚═╝
#
#         mamba (0.15.3) supported by @QuantStack
#
#         GitHub:  https://github.com/mamba-org/mamba
#         Twitter: https://twitter.com/QuantStack
#
# █████████████████████████████████████████████████████████████
#
#
# Looking for: ['pandas==1.3.3']
#
# pkgs/main/noarch         [<=>                 ] (00m:00s)
# pkgs/main/noarch         [=>                ] (00m:00s) 496  B / ?? (3.22 KB/s)
# pkgs/main/noarch         [=>                ] (00m:00s) 496  B / ?? (3.22 KB/s)
# pkgs/main/linux-64       [<=>                 ] (00m:00s)
# pkgs/main/noarch         [=>                ] (00m:00s) 496  B / ?? (3.22 KB/s)
# pkgs/main/linux-64       [=>                ] (00m:00s) 588 KB / ?? (1.90 MB/s)
# pkgs/main/noarch         [<=>               ] (00m:00s) 496  B / ?? (3.22 KB/s)
# pkgs/main/linux-64       [=>                ] (00m:00s) 588 KB / ?? (1.90 MB/s)
# pkgs/main/noarch         [<=>               ] (00m:00s) 644 KB / ?? (2.09 MB/s)
# pkgs/main/linux-64       [=>                ] (00m:00s) 588 KB / ?? (1.90 MB/s)
# pkgs/main/noarch         [<=>               ] (00m:00s) 644 KB / ?? (2.09 MB/s)
# pkgs/main/linux-64       [=>                ] (00m:00s) 588 KB / ?? (1.90 MB/s)
# pkgs/r/linux-64          [<=>                 ] (00m:00s)
# pkgs/main/noarch         [<=>               ] (00m:00s) 644 KB / ?? (2.09 MB/s)
# pkgs/main/linux-64       [=>                ] (00m:00s) 588 KB / ?? (1.90 MB/s)
# pkgs/r/linux-64          [=>                ] (00m:00s) 520 KB / ?? (1.68 MB/s)
# pkgs/main/noarch         [<=>               ] (00m:00s) 644 KB / ?? (2.09 MB/s)
# pkgs/main/linux-64       [=>                ] (00m:00s) 588 KB / ?? (1.90 MB/s)
# pkgs/r/linux-64          [=>                ] (00m:00s) 520 KB / ?? (1.68 MB/s)
# pkgs/r/noarch            [<=>                 ] (00m:00s)
# pkgs/main/noarch         [<=>               ] (00m:00s) 644 KB / ?? (2.09 MB/s)
# pkgs/main/linux-64       [=>                ] (00m:00s) 588 KB / ?? (1.90 MB/s)
# pkgs/r/linux-64          [=>                ] (00m:00s) 520 KB / ?? (1.68 MB/s)
# pkgs/r/noarch            [=>                ] (00m:00s) 652 KB / ?? (2.11 MB/s)
# pkgs/main/noarch         [ <=>                ] (00m:00s) Finalizing...
# pkgs/main/linux-64       [=>                ] (00m:00s) 588 KB / ?? (1.90 MB/s)
# pkgs/r/linux-64          [=>                ] (00m:00s) 520 KB / ?? (1.68 MB/s)
# pkgs/r/noarch            [=>                ] (00m:00s) 652 KB / ?? (2.11 MB/s)
# pkgs/main/noarch         [ <=>                ] (00m:00s) Done
# pkgs/main/linux-64       [=>                ] (00m:00s) 588 KB / ?? (1.90 MB/s)
# pkgs/r/linux-64          [=>                ] (00m:00s) 520 KB / ?? (1.68 MB/s)
# pkgs/r/noarch            [=>                ] (00m:00s) 652 KB / ?? (2.11 MB/s)
# pkgs/main/noarch         [====================] (00m:00s) Done
# pkgs/main/linux-64       [=>                ] (00m:00s) 588 KB / ?? (1.90 MB/s)
# pkgs/r/linux-64          [=>                ] (00m:00s) 520 KB / ?? (1.68 MB/s)
# pkgs/r/noarch            [=>                ] (00m:00s) 652 KB / ?? (2.11 MB/s)
# pkgs/main/linux-64       [=>                ] (00m:00s) 588 KB / ?? (1.90 MB/s)
# pkgs/r/linux-64          [=>                ] (00m:00s) 520 KB / ?? (1.68 MB/s)
# pkgs/r/noarch            [<=>                 ] (00m:00s) Finalizing...
# pkgs/main/linux-64       [=>                ] (00m:00s) 588 KB / ?? (1.90 MB/s)
# pkgs/r/linux-64          [=>                ] (00m:00s) 520 KB / ?? (1.68 MB/s)
# pkgs/r/noarch            [<=>                 ] (00m:00s) Done
# pkgs/r/noarch            [====================] (00m:00s) Done
# pkgs/main/linux-64       [=>                ] (00m:00s) 588 KB / ?? (1.90 MB/s)
# pkgs/r/linux-64          [=>                ] (00m:00s) 520 KB / ?? (1.68 MB/s)
# pkgs/main/linux-64       [<=>               ] (00m:00s) 588 KB / ?? (1.90 MB/s)
# pkgs/r/linux-64          [=>                ] (00m:00s) 520 KB / ?? (1.68 MB/s)
# pkgs/main/linux-64       [ <=>                ] (00m:00s) 1 MB / ?? (2.58 MB/s)
# pkgs/r/linux-64          [=>                ] (00m:00s) 520 KB / ?? (1.68 MB/s)
# pkgs/main/linux-64       [ <=>                ] (00m:00s) 1 MB / ?? (2.58 MB/s)
# pkgs/r/linux-64          [<=>               ] (00m:00s) 520 KB / ?? (1.68 MB/s)
# pkgs/main/linux-64       [ <=>                ] (00m:00s) 1 MB / ?? (2.58 MB/s)
# pkgs/r/linux-64          [ <=>                ] (00m:00s) 1 MB / ?? (2.47 MB/s)
# pkgs/main/linux-64       [ <=>                ] (00m:00s) 1 MB / ?? (2.58 MB/s)
# pkgs/r/linux-64          [ <=>                ] (00m:00s) Finalizing...
# pkgs/main/linux-64       [ <=>                ] (00m:00s) 1 MB / ?? (2.58 MB/s)
# pkgs/r/linux-64          [ <=>                ] (00m:00s) Done
# pkgs/r/linux-64          [====================] (00m:00s) Done
# pkgs/main/linux-64       [ <=>                ] (00m:00s) 1 MB / ?? (2.58 MB/s)
# pkgs/main/linux-64       [  <=>               ] (00m:00s) 1 MB / ?? (2.58 MB/s)
# pkgs/main/linux-64       [  <=>               ] (00m:00s) 2 MB / ?? (3.22 MB/s)
# pkgs/main/linux-64       [   <=>              ] (00m:00s) 2 MB / ?? (3.22 MB/s)
# pkgs/main/linux-64       [   <=>              ] (00m:00s) 3 MB / ?? (3.37 MB/s)
# pkgs/main/linux-64       [    <=>             ] (00m:00s) 3 MB / ?? (3.37 MB/s)
# pkgs/main/linux-64       [    <=>             ] (00m:00s) 3 MB / ?? (3.53 MB/s)
# pkgs/main/linux-64       [     <=>            ] (00m:00s) 3 MB / ?? (3.53 MB/s)
# pkgs/main/linux-64       [     <=>            ] (00m:00s) 4 MB / ?? (3.65 MB/s)
# pkgs/main/linux-64       [      <=>           ] (00m:00s) 4 MB / ?? (3.65 MB/s)
# pkgs/main/linux-64       [      <=>           ] (00m:00s) 5 MB / ?? (3.73 MB/s)
# pkgs/main/linux-64       [      <=>           ] (00m:00s) Finalizing...
# pkgs/main/linux-64       [      <=>           ] (00m:01s) Done
# pkgs/main/linux-64       [====================] (00m:01s) Done
#
# Pinned packages:
#   - python 3.7.*
#
#
# Transaction
#
#   Prefix: /home/jupyterlab/conda/envs/python
#
#   Updating specs:
#
#    - pandas==1.3.3
#    - ca-certificates
#    - certifi
#    - openssl
#
#
#   Package      Version  Build           Channel                  Size
# ───────────────────────────────────────────────────────────────────────
#   Change:
# ───────────────────────────────────────────────────────────────────────
#
#   - openssl     1.1.1q  h166bdaf_0      installed
#   + openssl     1.1.1q  h7f8727e_0      pkgs/main/linux-64       3 MB
#
#   Upgrade:
# ───────────────────────────────────────────────────────────────────────
#
#   - certifi  2022.9.14  pyhd8ed1ab_0    installed
#   + certifi  2022.9.24  py37h06a4308_0  pkgs/main/linux-64     154 KB
#
#   Downgrade:
# ───────────────────────────────────────────────────────────────────────
#
#   - pandas       1.3.5  py37h8c16a72_0  installed
#   + pandas       1.3.3  py37h8c16a72_0  pkgs/main/linux-64       9 MB
#
#   Summary:
#
#   Change: 1 packages
#   Upgrade: 1 packages
#   Downgrade: 1 packages
#
#   Total download: 12 MB
#
# ───────────────────────────────────────────────────────────────────────
#
# Downloading  [>                                        ] (00m:00s)    1.04 MB/s
# Extracting   [>                                                      ] (--:--)
# Finished certifi                              (00m:00s)             154 KB      1 MB/s
# Downloading  [>                                        ] (00m:00s)    1.04 MB/s
# Extracting   [>                                                      ] (--:--)
# Downloading  [>                                        ] (00m:00s)    1.04 MB/s
# Extracting   [>                                                      ] (--:--)
# Downloading  [>                                        ] (00m:00s)    1.04 MB/s
# Extracting   [>                                                      ] (--:--)
# Downloading  [>                                        ] (00m:00s)    2.28 MB/s
# Extracting   [>                                                      ] (--:--)
# Downloading  [>                                        ] (00m:00s)    2.28 MB/s
# Extracting   [>                                                      ] (--:--)
# Downloading  [====>                                    ] (00m:00s)    9.25 MB/s
# Extracting   [>                                                      ] (--:--)
# Downloading  [====>                                    ] (00m:00s)    9.25 MB/s
# Extracting   [>                                                      ] (--:--)
# Downloading  [====>                                    ] (00m:00s)    9.25 MB/s
# Extracting   [=============>                           ] (00m:00s)        1 / 3
# Downloading  [=========>                               ] (00m:00s)   17.40 MB/s
# Extracting   [=============>                           ] (00m:00s)        1 / 3
# Finished openssl                              (00m:00s)               3 MB     15 MB/s
# Downloading  [=========>                               ] (00m:00s)   17.40 MB/s
# Extracting   [=============>                           ] (00m:00s)        1 / 3
# Downloading  [=========>                               ] (00m:00s)   17.40 MB/s
# Extracting   [=============>                           ] (00m:00s)        1 / 3
# Downloading  [=========>                               ] (00m:00s)   17.40 MB/s
# Extracting   [=============>                           ] (00m:00s)        1 / 3
# Downloading  [=========================================] (00m:00s)   56.68 MB/s
# Extracting   [=============>                           ] (00m:00s)        1 / 3
# Finished pandas                               (00m:00s)               9 MB     44 MB/s
# Downloading  [=========================================] (00m:00s)   56.68 MB/s
# Extracting   [=============>                           ] (00m:00s)        1 / 3
# Downloading  [=========================================] (00m:00s)   56.68 MB/s
# Extracting   [=============>                           ] (00m:00s)        1 / 3
# Downloading  [=========================================] (00m:00s)   56.68 MB/s
# Extracting   [===========================>             ] (00m:00s)        2 / 3
# Downloading  [=========================================] (00m:00s)   56.68 MB/s
# Extracting   [===========================>             ] (00m:00s)        2 / 3
# Downloading  [=========================================] (00m:00s)   56.68 MB/s
# Extracting   [=========================================] (00m:00s)        3 / 3
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
#
#                   __    __    __    __
#                  /  \  /  \  /  \  /  \
#                 /    \/    \/    \/    \
# ███████████████/  /██/  /██/  /██/  /████████████████████████
#               /  / \   / \   / \   / \  \____
#              /  /   \_/   \_/   \_/   \    o \__,
#             / _/                       \_____/  `
#             |/
#         ███╗   ███╗ █████╗ ███╗   ███╗██████╗  █████╗
#         ████╗ ████║██╔══██╗████╗ ████║██╔══██╗██╔══██╗
#         ██╔████╔██║███████║██╔████╔██║██████╔╝███████║
#         ██║╚██╔╝██║██╔══██║██║╚██╔╝██║██╔══██╗██╔══██║
#         ██║ ╚═╝ ██║██║  ██║██║ ╚═╝ ██║██████╔╝██║  ██║
#         ╚═╝     ╚═╝╚═╝  ╚═╝╚═╝     ╚═╝╚═════╝ ╚═╝  ╚═╝
#
#         mamba (0.15.3) supported by @QuantStack
#
#         GitHub:  https://github.com/mamba-org/mamba
#         Twitter: https://twitter.com/QuantStack
#
# █████████████████████████████████████████████████████████████
#
#
# Looking for: ['requests==2.26.0']
#
# pkgs/main/linux-64       Using cache
# pkgs/main/noarch         Using cache
# pkgs/r/linux-64          Using cache
# pkgs/r/noarch            Using cache
#
# Pinned packages:
#   - python 3.7.*
#
#
# Transaction
#
#   Prefix: /home/jupyterlab/conda/envs/python
#
#   Updating specs:
#
#    - requests==2.26.0
#    - ca-certificates
#    - certifi
#    - openssl
#
#
#   Package               Version  Build         Channel               Size
# ───────────────────────────────────────────────────────────────────────────
#   Downgrade:
# ───────────────────────────────────────────────────────────────────────────
#
#   - charset-normalizer    2.1.1  pyhd8ed1ab_0  installed
#   + charset-normalizer    2.0.4  pyhd3eb1b0_0  pkgs/main/noarch     35 KB
#   - requests             2.28.1  pyhd8ed1ab_1  installed
#   + requests             2.26.0  pyhd3eb1b0_0  pkgs/main/noarch     59 KB
#
#   Summary:
#
#   Downgrade: 2 packages
#
#   Total download: 94 KB
#
# ───────────────────────────────────────────────────────────────────────────
#
# Downloading  [==============>                          ] (00m:00s)  224.30 KB/s
# Extracting   [>                                                      ] (--:--)
# Finished charset-normalizer                   (00m:00s)              35 KB    224 KB/s
# Downloading  [==============>                          ] (00m:00s)  224.30 KB/s
# Extracting   [>                                                      ] (--:--)
# Downloading  [==============>                          ] (00m:00s)  224.30 KB/s
# Extracting   [>                                                      ] (--:--)
# Downloading  [==============>                          ] (00m:00s)  224.30 KB/s
# Extracting   [>                                                      ] (--:--)
# Downloading  [=========================================] (00m:00s)  601.29 KB/s
# Extracting   [>                                                      ] (--:--)
# Finished requests                             (00m:00s)              59 KB    380 KB/s
# Downloading  [=========================================] (00m:00s)  601.29 KB/s
# Extracting   [>                                                      ] (--:--)
# Downloading  [=========================================] (00m:00s)  601.29 KB/s
# Extracting   [>                                                      ] (--:--)
# Downloading  [=========================================] (00m:00s)  601.29 KB/s
# Extracting   [====================>                    ] (00m:00s)        1 / 2
# Downloading  [=========================================] (00m:00s)  601.29 KB/s
# Extracting   [====================>                    ] (00m:00s)        1 / 2
# Downloading  [=========================================] (00m:00s)  601.29 KB/s
# Extracting   [=========================================] (00m:00s)        2 / 2
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done

# %% [markdown]
# ## Imports
#
# Import any additional libraries you may need here.

# %%
import requests
import pandas as pd
import json

# %% [markdown]
# ## Extract Data Using an API

# %% [markdown]
# Using ExchangeRate-API we will extract currency exchange rate data. Use the below steps to get the access key and to get the data.
#
# 1.  Open the url : [https://exchangeratesapi.io/](https://exchangeratesapi.io/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkPY0221ENSkillsNetwork23455645-2022-01-01) and click on **Get Free API Key**.
# 2.  Subscribe for Free plan and Sign-in with the Google Account.
# 3.  Once the account is created you will be redirected to [https://apilayer.com](https://apilayer.com/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkPY0221ENSkillsNetwork23455645-2022-01-01) website.
# 4.  Now, click on the **user icon** and click **Account** as shown below:
#
# <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-PY0221EN-SkillsNetwork/labs/module%206/Final%20Assignment/Images/account.png"/>
#
# 3.  Scroll down and you will get the API Key section. Copy the API key and use in the url in Question 1.

# %% [markdown]
# ### Call the API
#
# <b> Question 1</b> Using the `requests` library call the endpoint given above and save the text, remember the first few characters of the output:

# %%
# Write your code here
url = "https://api.apilayer.com/exchangerates_data/latest?base=EUR&apikey=potW2Sip7bDzk0GP7VpSPyO69OqpwRPm" #Make sure to change ******* to your API key.
data = requests.get(url)

#data.json()
# Out:
# {'success': True,
#  'timestamp': 1666897563,
#  'base': 'EUR',
#  'date': '2022-10-27',
#  'rates': {'AED': 3.659724,
#   'AFN': 86.68342,
#   'ALL': 116.698517,
#   'AMD': 395.256501,
#   'ANG': 1.79581,
#   'AOA': 479.126244,
#   'ARS': 155.129521,
#   'AUD': 1.541551,
#   'AWG': 1.795936,
#   'AZN': 1.70437,
#   'BAM': 1.941891,
#   'BBD': 2.011908,
#   'BDT': 100.950097,
#   'BGN': 1.953308,
#   'BHD': 0.375569,
#   'BIF': 2043.530895,
#   'BMD': 0.996358,
#   'BND': 1.404419,
#   'BOB': 6.885477,
#   'BRL': 5.287278,
#   'BSD': 0.996438,
#   'BTC': 4.8287462e-05,
#   'BTN': 81.996409,
#   'BWP': 13.268263,
#   'BYN': 2.52309,
#   'BYR': 19528.622883,
#   'BZD': 2.008573,
#   'CAD': 1.351092,
#   'CDF': 2004.673126,
#   'CHF': 0.988208,
#   'CLF': 0.033955,
#   'CLP': 936.925463,
#   'CNY': 7.202475,
#   'COP': 4805.147187,
#   'CRC': 621.304149,
#   'CUC': 0.996358,
#   'CUP': 26.403495,
#   'CVE': 109.170728,
#   'CZK': 24.47756,
#   'DJF': 177.073015,
#   'DKK': 7.441113,
#   'DOP': 53.753181,
#   'DZD': 140.292682,
#   'EGP': 23.067424,
#   'ERN': 14.945375,
#   'ETB': 52.683475,
#   'EUR': 1,
#   'FJD': 2.274835,
#   'FKP': 0.879311,
#   'GBP': 0.861536,
#   'GEL': 2.76004,
#   'GGP': 0.879311,
#   'GHS': 13.948976,
#   'GIP': 0.879311,
#   'GMD': 57.838492,
#   'GNF': 8693.226443,
#   'GTQ': 7.812126,
#   'GYD': 208.472573,
#   'HKD': 7.820964,
#   'HNL': 24.711596,
#   'HRK': 7.532566,
#   'HTG': 125.552803,
#   'HUF': 408.998089,
#   'IDR': 15498.403336,
#   'ILS': 3.495155,
#   'IMP': 0.879311,
#   'INR': 82.096487,
#   'IQD': 1454.683133,
#   'IRR': 42195.774636,
#   'ISK': 143.196876,
#   'JEP': 0.879311,
#   'JMD': 152.245679,
#   'JOD': 0.706379,
#   'JPY': 145.738822,
#   'KES': 120.908156,
#   'KGS': 82.629091,
#   'KHR': 4129.905253,
#   'KMF': 486.723176,
#   'KPW': 896.722342,
#   'KRW': 1414.301085,
#   'KWD': 0.308272,
#   'KYD': 0.83034,
#   'KZT': 462.481818,
#   'LAK': 16813.546666,
#   'LBP': 1516.956539,
#   'LKR': 365.696493,
#   'LRD': 153.065515,
#   'LSL': 17.874863,
#   'LTL': 2.941987,
#   'LVL': 0.602687,
#   'LYD': 4.976788,
#   'MAD': 10.825418,
#   'MDL': 19.281302,
#   'MGA': 4244.486693,
#   'MKD': 61.17589,
#   'MMK': 2092.540303,
#   'MNT': 3347.539903,
#   'MOP': 8.055777,
#   'MRO': 355.699745,
#   'MUR': 43.636422,
#   'MVR': 15.367512,
#   'MWK': 1024.25632,
#   'MXN': 19.786378,
#   'MYR': 4.697828,
#   'MZN': 63.597355,
#   'NAD': 17.874908,
#   'NGN': 436.066154,
#   'NIO': 36.138181,
#   'NOK': 10.237238,
#   'NPR': 131.196295,
#   'NZD': 1.707749,
#   'OMR': 0.383599,
#   'PAB': 0.996438,
#   'PEN': 3.975195,
#   'PGK': 3.506927,
#   'PHP': 58.015934,
#   'PKR': 220.568832,
#   'PLN': 4.720791,
#   'PYG': 7235.167207,
#   'QAR': 3.627491,
#   'RON': 4.896997,
#   'RSD': 117.306295,
#   'RUB': 61.101663,
#   'RWF': 1043.187151,
#   'SAR': 3.742792,
#   'SBD': 8.173841,
#   'SCR': 14.420331,
#   'SDG': 569.916712,
#   'SEK': 10.922703,
#   'SGD': 1.403625,
#   'SHP': 1.372381,
#   'SLL': 17112.453693,
#   'SOS': 567.429878,
#   'SRD': 28.695616,
#   'STD': 20622.605385,
#   'SVC': 8.71937,
#   'SYP': 2503.380179,
#   'SZL': 17.874903,
#   'THB': 37.659468,
#   'TJS': 10.120995,
#   'TMT': 3.497218,
#   'TND': 3.213261,
#   'TOP': 2.403067,
#   'TRY': 18.528182,
#   'TTD': 6.760872,
#   'TWD': 31.943544,
#   'TZS': 2323.507546,
#   'UAH': 36.709208,
#   'UGX': 3801.357279,
#   'USD': 0.996358,
#   'UYU': 41.038433,
#   'UZS': 11134.304055,
#   'VND': 24749.54043,
#   'VUV': 124.694134,
#   'WST': 2.834577,
#   'XAF': 651.282208,
#   'XAG': 0.051186,
#   'XAU': 0.000601,
#   'XCD': 2.692708,
#   'XDR': 0.772058,
#   'XOF': 649.129012,
#   'XPF': 118.252819,
#   'YER': 249.338855,
#   'ZAR': 17.897016,
#   'ZMK': 8968.421242,
#   'ZMW': 16.067688,
#   'ZWL': 320.826969}}

# %% [markdown]
# ### Save as DataFrame
#
# <b> Question 2</b>  Using the data gathered turn it into a `pandas` dataframe. The dataframe should have the Currency as the index and `Rate` as their columns. Make sure to drop unnecessary columns.

# %%
# Turn the data into a dataframe

exchange_rates=pd.read_json(data)
exchange_rates
# Out:
#      success           timestamp base       date        rates
# AED     True 2022-10-27 18:25:04  EUR 2022-10-27     3.660105
# AFN     True 2022-10-27 18:25:04  EUR 2022-10-27    86.691796
# ALL     True 2022-10-27 18:25:04  EUR 2022-10-27   116.710689
# AMD     True 2022-10-27 18:25:04  EUR 2022-10-27   395.300686
# ANG     True 2022-10-27 18:25:04  EUR 2022-10-27     1.795998
# ..       ...                 ...  ...        ...          ...
# YER     True 2022-10-27 18:25:04  EUR 2022-10-27   249.364365
# ZAR     True 2022-10-27 18:25:04  EUR 2022-10-27    17.888152
# ZMK     True 2022-10-27 18:25:04  EUR 2022-10-27  8969.354116
# ZMW     True 2022-10-27 18:25:04  EUR 2022-10-27    16.069373
# ZWL     True 2022-10-27 18:25:04  EUR 2022-10-27   320.860618
#
# [167 rows x 5 columns]

# %%
# Drop unnescessary columns

exchange_rates = exchange_rates.drop(columns=['success', 'timestamp', 'base', 'date'])

exchange_rates
# Out:
#            rates
# AED     3.660105
# AFN    86.691796
# ALL   116.710689
# AMD   395.300686
# ANG     1.795998
# ..           ...
# YER   249.364365
# ZAR    17.888152
# ZMK  8969.354116
# ZMW    16.069373
# ZWL   320.860618
#
# [167 rows x 1 columns]

# %% [markdown]
# ### Load the Data
#
# Using the dataframe save it as a CSV names `exchange_rates_1.csv`.

# %%
# Save the Dataframe
def load(targetfile, data_to_load):
    data_to_load.to_csv(targetfile)
targetfile= 'exchange_rates_1.csv'
load(targetfile, exchange_rates)

targetfile
# Out:
# 'exchange_rates_1.csv'

# %% [markdown]
# Your CSV should be in this format with more currencies
#
# |     | Rates      |
# | --- | ---------- |
# | AED | 4.398618   |
# | AFN | 92.917693  |
# | ALL | 123.099093 |
# | AMD | 621.935674 |
# | ANG | 2.149648   |

# %% [markdown]
# ## Authors

# %% [markdown]
# Ramesh Sannareddy, Joseph Santarcangelo and Azim Hirjani

# %% [markdown]
# ### Other Contributors

# %% [markdown]
# Rav Ahuja

# %% [markdown]
# ## Change Log

# %% [markdown]
# | Date (YYYY-MM-DD) | Version | Changed By        | Change Description                              |
# | ----------------- | ------- | ----------------- | ----------------------------------------------- |
# | 2022-05-06        | 0.3     | Malika            | Updated instructions to get the API and the url |
# | 2021-04-15        | 0.2     | Malika            | Updated the lab from USD to EUR                 |
# | 2020-11-25        | 0.1     | Ramesh Sannareddy | Created initial version of the lab              |

# %% [markdown]
# Copyright © 2020 IBM Corporation. This notebook and its source code are released under the terms of the [MIT License](https://cognitiveclass.ai/mit-license?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkPY0221ENSkillsNetwork23455645-2022-01-01&cm_mmc=Email_Newsletter-\_-Developer_Ed%2BTech-\_-WW_WW-\_-SkillsNetwork-Courses-IBM-DA0321EN-SkillsNetwork-21426264&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ).
